# %%
import pandas as pd

# %%
df=pd.DataFrame({
    "Order Date":[
        "2024-01-10",
        "2024-01-15",
        "2024-02-05",
        "2024-02-12",
        "2024-03-01",
        "2024-03-15",
        "2024-04-10",
        "2024-04-20",
        "2024-05-05",
        "2024-01-15"
    ],
    "Product Name":[
        "Laptop",
        "Mouse",
        "Printer",
        "Tablet",
        "Laptop",
        "Moniter",
        "Mouse",
        "Printer",
        "Smartwatch",
        "Mouse"
    ],
    "Category":[
        "Electronics",
        "Accessories",
        "Office",
        "Electronics",
        "Electronics",
        "Accessories",
        "Accessories",
        "Office",
        "Electronics",
        "Accessories",
    ],
    "Region":[
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",
        "East",
        "West",
        "North",
        "South"
    ],
    "Quantity":[
        2,
        5,
        3,
        4,
        1,
        2,
        6,
        2,
        3,
        5
    ],
    "Sales":[
        50000,
        2500,
        9000,
        30000,
        55000,
        16000,
        3000,
        6000,
        45000,
        2500
    ],
    "Profit":[
        10000,
        500,
        1500,
        6000,
        11000,
        3000,
        None,
        1000,
        9000,
        500
    ]
})

# %%
print("ORIGINAL DATASET")
# Out:
# ORIGINAL DATASET

# %%
display(df)
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales   Profit
# 0  2024-01-10       Laptop  Electronics  North         2  50000  10000.0
# 1  2024-01-15        Mouse  Accessories  South         5   2500    500.0
# 2  2024-02-05      Printer       Office   East         3   9000   1500.0
# 3  2024-02-12       Tablet  Electronics   West         4  30000   6000.0
# 4  2024-03-01       Laptop  Electronics  North         1  55000  11000.0
# 5  2024-03-15      Moniter  Accessories  South         2  16000   3000.0
# 6  2024-04-10        Mouse  Accessories   East         6   3000      NaN
# 7  2024-04-20      Printer       Office   West         2   6000   1000.0
# 8  2024-05-05   Smartwatch  Electronics  North         3  45000   9000.0
# 9  2024-01-15        Mouse  Accessories  South         5   2500    500.0

# %%
print("First 5 Records")
# Out:
# First 5 Records

# %%
display(df.head())
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales   Profit
# 0  2024-01-10       Laptop  Electronics  North         2  50000  10000.0
# 1  2024-01-15        Mouse  Accessories  South         5   2500    500.0
# 2  2024-02-05      Printer       Office   East         3   9000   1500.0
# 3  2024-02-12       Tablet  Electronics   West         4  30000   6000.0
# 4  2024-03-01       Laptop  Electronics  North         1  55000  11000.0

# %%
print("DATASET SHAPE")
# Out:
# DATASET SHAPE

# %%
print(df.shape)
# Out:
# (10, 7)

# %%
print("COLUMN NAMES")
# Out:
# COLUMN NAMES

# %%
print(df.columns)
# Out:
# Index(['Order Date', 'Product Name', 'Category', 'Region', 'Quantity', 'Sales',
#        'Profit'],
#       dtype='str')

# %%
print("DATA TYPES")
# Out:
# DATA TYPES

# %%
print(df.dtypes)
# Out:
# Order Date          str
# Product Name        str
# Category            str
# Region              str
# Quantity          int64
# Sales             int64
# Profit          float64
# dtype: object

# %%
print("DESCRIPTIVE STATISTICS")
# Out:
# DESCRIPTIVE STATISTICS

# %%
display(df.describe())
# Out:
#         Quantity         Sales        Profit
# count  10.000000     10.000000      9.000000
# mean    3.300000  21900.000000   4722.222222
# std     1.636392  21209.012759   4330.928820
# min     1.000000   2500.000000    500.000000
# 25%     2.000000   3750.000000   1000.000000
# 50%     3.000000  12500.000000   3000.000000
# 75%     4.750000  41250.000000   9000.000000
# max     6.000000  55000.000000  11000.000000

# %%
print("MISSING VALUES")
# Out:
# MISSING VALUES

# %%
print(df.isnull().sum())
# Out:
# Order Date      0
# Product Name    0
# Category        0
# Region          0
# Quantity        0
# Sales           0
# Profit          1
# dtype: int64

# %%
print("ROWS CONTAINING MISSING VALUES")
# Out:
# ROWS CONTAINING MISSING VALUES

# %%
display(df[df.isnull().any(axis=1)])
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit
# 6  2024-04-10        Mouse  Accessories   East         6   3000     NaN

# %%
print("TOTAL DUPLICATE RECORDS")
# Out:
# TOTAL DUPLICATE RECORDS

# %%
print(df.duplicated().sum())
# Out:
# 1

# %%
print("DUPLICATE RECORDS")
# Out:
# DUPLICATE RECORDS

# %%
display(df[df.duplicated()])
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit
# 9  2024-01-15        Mouse  Accessories  South         5   2500   500.0

# %%
import pandas as pd

# %%
new_sales=pd.DataFrame({
    "Order Date":[
        "2024-06-01",
        "2024-06-05",
        "2024-06-10",
    ],
    "Product Name":[
        "Laptop",
        "Mouse",
        "Printer",
    ],
    "Category":[
        "Electronics",
        "Accessories",
        "Office"
    ],
    "Region":[
        "North",
        "South",
        "East",
    ],
    "Quantity":[
        2,
        4,
        3
    ],
    "Sales":[
        60000,
        2000,
        9000
    ],
    "Profit":[
        12000,
        400,
        1800
    ]
})

# %%
print("NEW SALES DATA")
# Out:
# NEW SALES DATA

# %%
display(new_sales)
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit
# 0  2024-06-01       Laptop  Electronics  North         2  60000   12000
# 1  2024-06-05        Mouse  Accessories  South         4   2000     400
# 2  2024-06-10      Printer       Office   East         3   9000    1800

# %%
combined_df=pd.concat(
    [df,new_sales],
    ignore_index=True
)

# %%
print("CONCATENATED DATA")
# Out:
# CONCATENATED DATA

# %%
display(combined_df)
# Out:
#     Order Date Product Name     Category Region  Quantity  Sales   Profit
# 0   2024-01-10       Laptop  Electronics  North         2  50000  10000.0
# 1   2024-01-15        Mouse  Accessories  South         5   2500    500.0
# 2   2024-02-05      Printer       Office   East         3   9000   1500.0
# 3   2024-02-12       Tablet  Electronics   West         4  30000   6000.0
# 4   2024-03-01       Laptop  Electronics  North         1  55000  11000.0
# 5   2024-03-15      Moniter  Accessories  South         2  16000   3000.0
# 6   2024-04-10        Mouse  Accessories   East         6   3000      NaN
# 7   2024-04-20      Printer       Office   West         2   6000   1000.0
# 8   2024-05-05   Smartwatch  Electronics  North         3  45000   9000.0
# 9   2024-01-15        Mouse  Accessories  South         5   2500    500.0
# 10  2024-06-01       Laptop  Electronics  North         2  60000  12000.0
# 11  2024-06-05        Mouse  Accessories  South         4   2000    400.0
# 12  2024-06-10      Printer       Office   East         3   9000   1800.0

# %%
import pandas as pd

# %%
product_info=pd.DataFrame({
    "Product Name":[
        "Laptop",
        "Mouse",
        "Printer",
        "Tablet",
        "Moniter",
    ],
    "Supplier":[
        "DELL",
        "Logitech",
        "HP",
        "Samsung",
        "LG"
    ],
    "Discount":[
        10,
        5,
        15,
        8,
        12
    ]
})

# %%
print("PRODUCT INFORMATION")
# Out:
# PRODUCT INFORMATION

# %%
display(product_info)
# Out:
#   Product Name  Supplier  Discount
# 0       Laptop      DELL        10
# 1        Mouse  Logitech         5
# 2      Printer        HP        15
# 3       Tablet   Samsung         8
# 4      Moniter        LG        12

# %%
merged_df=pd.merge(
    df,
    product_info,
    on="Product Name",
    how="left"
)

# %%
print("MERGED DATA")
# Out:
# MERGED DATA

# %%
display(merged_df)
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales   Profit  \
# 0  2024-01-10       Laptop  Electronics  North         2  50000  10000.0
# 1  2024-01-15        Mouse  Accessories  South         5   2500    500.0
# 2  2024-02-05      Printer       Office   East         3   9000   1500.0
# 3  2024-02-12       Tablet  Electronics   West         4  30000   6000.0
# 4  2024-03-01       Laptop  Electronics  North         1  55000  11000.0
# 5  2024-03-15      Moniter  Accessories  South         2  16000   3000.0
# 6  2024-04-10        Mouse  Accessories   East         6   3000      NaN
# 7  2024-04-20      Printer       Office   West         2   6000   1000.0
# 8  2024-05-05   Smartwatch  Electronics  North         3  45000   9000.0
# 9  2024-01-15        Mouse  Accessories  South         5   2500    500.0
#
#    Supplier  Discount
# 0      DELL      10.0
# 1  Logitech       5.0
# 2        HP      15.0
# 3   Samsung       8.0
# 4      DELL      10.0
# 5        LG      12.0
# 6  Logitech       5.0
# 7        HP      15.0
# 8       NaN       NaN
# 9  Logitech       5.0

# %%
region_info=pd.DataFrame(
    {
        "Region_Manager":[
            "Manager A",
            "Manager B",
            "Manager C",
            "Maneger D"
        ]
    },
    index=[
        "North",
        "South",
        "East",
        "West",
    ]
)

# %%
print("REGION INFORMATION")
# Out:
# REGION INFORMATION

# %%
display(region_info)
# Out:
#       Region_Manager
# North      Manager A
# South      Manager B
# East       Manager C
# West       Maneger D

# %%
df_region=df.set_index("Region")

# %%
joined_df=df_region.join(region_info)

# %%
print("JOINED DATA")
# Out:
# JOINED DATA

# %%
display(joined_df)
# Out:
#         Order Date Product Name     Category  Quantity  Sales   Profit  \
# Region
# North   2024-01-10       Laptop  Electronics         2  50000  10000.0
# South   2024-01-15        Mouse  Accessories         5   2500    500.0
# East    2024-02-05      Printer       Office         3   9000   1500.0
# West    2024-02-12       Tablet  Electronics         4  30000   6000.0
# North   2024-03-01       Laptop  Electronics         1  55000  11000.0
# South   2024-03-15      Moniter  Accessories         2  16000   3000.0
# East    2024-04-10        Mouse  Accessories         6   3000      NaN
# West    2024-04-20      Printer       Office         2   6000   1000.0
# North   2024-05-05   Smartwatch  Electronics         3  45000   9000.0
# South   2024-01-15        Mouse  Accessories         5   2500    500.0
#
#        Region_Manager
# Region
# North       Manager A
# South       Manager B
# East        Manager C
# West        Maneger D
# North       Manager A
# South       Manager B
# East        Manager C
# West        Maneger D
# North       Manager A
# South       Manager B

# %%
region_sales=df.groupby(
    "Region"
)["Sales"].sum()

# %%
print("TOTAL SALES BY REGION")
# Out:
# TOTAL SALES BY REGION

# %%
display(region_sales)
# Out:
# Region
# East      12000
# North    150000
# South     21000
# West      36000
# Name: Sales, dtype: int64

# %%
pivot_table=pd.pivot_table(
    df,
    values="Sales",
    index="Category",
    columns="Region",
    aggfunc="sum",
    fill_value=0
)

# %%
print("PIVOT TABLE")
# Out:
# PIVOT TABLE

# %%
display(pivot_table)
# Out:
# Region       East   North  South   West
# Category
# Accessories  3000       0  21000      0
# Electronics     0  150000      0  30000
# Office       9000       0      0   6000
