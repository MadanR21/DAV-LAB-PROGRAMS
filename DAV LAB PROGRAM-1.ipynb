# %%
import numpy as np

# %%
arr=np.array([10,20,30,40,50])

# %%
print("Numpy Array")
# Out:
# Numpy Array

# %%
print(arr)
# Out:
# [10 20 30 40 50]

# %%
print("\n--Array Indexing--")
# Out:
# --Array Indexing--

# %%
print("First Element:",arr[0])
# Out:
# First Element: 10

# %%
print("Third Element:",arr[2])
# Out:
# Third Element: 30

# %%
print("Last Element:",arr[-1])
# Out:
# Last Element: 50

# %%
print("\n--Array Slicing---")
# Out:
# --Array Slicing---

# %%
print("First three elements:",arr[0:3])
# Out:
# First three elements: [10 20 30]

# %%
print("Elements from index 2:",arr[2:])
# Out:
# Elements from index 2: [30 40 50]

# %%
print("Last three elements:",arr[-3:])
# Out:
# Last three elements: [30 40 50]

# %%
print("\n---Basic Array Operations---")
# Out:
# ---Basic Array Operations---

# %%
print("Add 5:",arr+5)
# Out:
# Add 5: [15 25 35 45 55]

# %%
print("Subtract 5:",arr-5)
# Out:
# Subtract 5: [ 5 15 25 35 45]

# %%
print("Multiply by 2:",arr*2)
# Out:
# Multiply by 2: [ 20  40  60  80 100]

# %%
print("Divide by 10:",arr/10)
# Out:
# Divide by 10: [1. 2. 3. 4. 5.]

# %%
print("\n---Mathematical Operations---")
# Out:
# ---Mathematical Operations---

# %%
print("Sum:",np.sum(arr))
# Out:
# Sum: 150

# %%
print("Mean:",np.mean(arr))
# Out:
# Mean: 30.0

# %%
print("Maximum:",np.max(arr))
# Out:
# Maximum: 50

# %%
print("Minimum:",np.min(arr))
# Out:
# Minimum: 10

# %%
print("\n---Array Reshaping---")
# Out:
# ---Array Reshaping---

# %%
reshaped_arr=arr.reshape(5,1)

# %%
print("Reshaped Array:")
# Out:
# Reshaped Array:

# %%
print(reshaped_arr)
# Out:
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]]

# %%
import pandas as pd

# %%
data={
    "Name":["Asha","Ravi","Meera","Karan"],
    "Marks":[88,72,91,65],
    "Branch":["CSE","ECE","CSE","ISE"]
}

# %%
df=pd.DataFrame(data)

# %%
print("\n---Pandas DataFrame---")
# Out:
# ---Pandas DataFrame---

# %%
print(df)
# Out:
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
# 3  Karan     65    ISE

# %%
print("\n---Column Indexing---")
# Out:
# ---Column Indexing---

# %%
print("Name Column:")
# Out:
# Name Column:

# %%
print(df["Name"])
# Out:
# 0     Asha
# 1     Ravi
# 2    Meera
# 3    Karan
# Name: Name, dtype: str

# %%
print("\nMarks Column:")
# Out:
# Marks Column:

# %%
print(df["Marks"])
# Out:
# 0    88
# 1    72
# 2    91
# 3    65
# Name: Marks, dtype: int64

# %%
print("\n---Row Indexing---")
# Out:
# ---Row Indexing---

# %%
print("First Row:")
# Out:
# First Row:

# %%
print(df.iloc[0])
# Out:
# Name      Asha
# Marks       88
# Branch     CSE
# Name: 0, dtype: object

# %%
print("\nThird Row:")
# Out:
# Third Row:

# %%
print(df.iloc[2])
# Out:
# Name      Meera
# Marks        91
# Branch      CSE
# Name: 2, dtype: object

# %%
print("\n---Specific Value---")
# Out:
# ---Specific Value---

# %%
print("Marks of first student:",df.iloc[0,1])
# Out:
# Marks of first student: 88

# %%
print("\n---Row Slicing---")
# Out:
# ---Row Slicing---

# %%
print("First two rows:")
# Out:
# First two rows:

# %%
print(df.iloc[0:2])
# Out:
#    Name  Marks Branch
# 0  Asha     88    CSE
# 1  Ravi     72    ECE

# %%
print("First three rows with Names and Marks:")
# Out:
# First three rows with Names and Marks:

# %%
print(df.iloc[0:3,[0,1]])
# Out:
#     Name  Marks
# 0   Asha     88
# 1   Ravi     72
# 2  Meera     91

# %%
print("\n---Data Filtering---")
# Out:
# ---Data Filtering---

# %%
result=df[df["Marks"]>70]

# %%
print("Students with Marks Greater thsn 70:")
# Out:
# Students with Marks Greater thsn 70:

# %%
print(result)
# Out:
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
